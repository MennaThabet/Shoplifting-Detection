# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_216.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_98.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_137.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_86_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_19_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_202.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_159.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_217.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_185_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_40_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_107.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_37.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_218_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_140_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_32_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_190.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_39.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_212.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_173.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_70_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_77.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_44.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_0.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_154.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_98_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_34.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videossssstttsss_48.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_130.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_96_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_123.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_93.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_16_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_47.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_24_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_213_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_214_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_36.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_170.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_35.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_7_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_49.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_169.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_80_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_46.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_56.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_123_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_80.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_3.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_120.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_172.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_101.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_11.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_121_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_67.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_31_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_211.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_27.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_151_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_117_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_72.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_113_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_29.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_12.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_130_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_199_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_10.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_61_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_124.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_40.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_168_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_42.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_14.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_122.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_201.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_65.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_52_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_13.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_4.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_179_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_162_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_78.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_191_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_178.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_75_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_194.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_195.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_63_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_54_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_202_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_63.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_53_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_165_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_106.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_36.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_118.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_79_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_158_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_27_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_39.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_194_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_21.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_29.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_76.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_107_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_59.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_134.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_82_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_177.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_119.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_154_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_22.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_100.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_25_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_115_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_92.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_211_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_156.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_213.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_167_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_181.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_12.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_63.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_76.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_197.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_75.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_163.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_156_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_26.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_49_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_207.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_64.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_136_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videossssstttsss_53.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_2.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_104_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_47.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_2.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_104.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_29_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_110.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_149_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_218.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_56_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_0.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_180_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_24.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_16.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_166.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_180.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_196.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_96.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_32.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_26.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_53.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_18_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_82.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_2_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_146_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_46_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_66.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_45.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_155.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_116_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_4_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_139_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_184_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_56.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_209.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_152.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_8.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_109.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_198.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_59.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_214.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_94_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_113.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_64_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_83_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_70.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_131.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_37.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_69_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_57.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_197_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_50.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_110_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_68_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_62.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_129.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_6.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_157_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_3.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_10_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_147_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_78.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_45.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_73.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_25.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_164_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_111.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_192.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_132_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_68.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_94.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_198_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_31.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_54.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_51_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_205_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_210_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_151.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_86.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_217_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_124_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_90.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_187.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_60.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videossssstttsss_51.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_39_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_11_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_160_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_176.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_23.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_20_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_42_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_84.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_200_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_89.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_22_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_167.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_195_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_8_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_8.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_186_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_142_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_108.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_79.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videossssstttsss_54.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_91_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_18.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_11.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_133.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_138.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_97.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_84.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_103.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_19.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_179.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_131_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_62_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_207_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_10.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_125_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_85.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_150_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_190_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_115.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_141_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_153.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_140.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_148.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_73_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_209_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_65.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_67.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_172_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_95.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_67_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_74.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_21_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_70.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_13_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_17_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_57.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_59_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_128_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_5.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_128.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_100_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_181_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_203_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_118_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_88.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_54.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_127_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_106_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_42.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videossssstttsss_55.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_120_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_174.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_146.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_55.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_30.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_157.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_43.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_55.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_33_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_185.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_145_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_116.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_216_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_206.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_81.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_99.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_114.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_57_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_134_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_117.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_112.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_68.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_62.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_46.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_165.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videossssstttsss_49.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_7.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_20.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_17.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_189.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_20.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_127.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_164.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_132.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_129_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_43_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_71.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_1_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_69.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_161.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_149.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_169_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_163_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_49.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_126.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_81_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_182.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_38.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_88_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_52.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_12_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_22.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_36_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_136.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_199.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_83.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_40.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_58_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_15.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_186.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_95_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_44.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_41.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_193_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_174_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_74_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_121.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_30.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_53.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_84_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_64.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_135.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_82.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_27.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_133_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_65_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_35.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_109_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_9.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_80.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_34.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_112_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_73.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_114_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_97_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_138_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_150.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_175.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_15_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_33.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_38.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_66.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_208.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_141.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_187_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_47_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_26_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_122_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_161_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_25.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_152_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_30_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_182_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_215_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_9_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_144.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_93_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_188_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_77_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_48.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_177_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_102_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videossssstttsss_52.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_43.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_160.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_191.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_75.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_87.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_183.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videossssstttsss_56.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_176_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_58.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_7.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_76_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_0_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_103_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_44_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_21.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_45_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_74.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_19.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_204.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_35_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_58.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_148_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_142.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_173_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_79.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_9.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_166_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_24.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_105.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_50.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_34_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_178_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_210.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_87_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/videppppsss_14.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_144_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_158.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_105_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_155_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_162.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_18.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_188.mp4
# ...
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_12.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_115.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_15.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_29.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_41.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_43.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_116.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_7.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_41.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_124.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_105.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_5.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videmmmmmmsss_93.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_3.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_9.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_11.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_15.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_38.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_60.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_66.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_20.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_17.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_103.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_104.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_29.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_49.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_21.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_17.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_10.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_43.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_7.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_38.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_14.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_85.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_22.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_17.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videmmmmmmsss_97.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_0.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_102.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_15.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_21.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videmmmmmmsss_96.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_44.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_46.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_69.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_18.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_30.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_21.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_54.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_27.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_110.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_72.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_10.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_37.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_9.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_12.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videmmmmmmsss_100.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_108.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_10.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_9.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_37.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_68.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_22.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_0.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_8.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_23.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_30.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_15.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_76.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_24.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_113.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_84.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_9.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_26.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_4.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_111.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_43.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_28.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_80.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_7.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_98.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_19.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_57.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_97.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_19.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_55.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_63.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_100.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_58.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_24.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_24.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_14.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_2.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_14.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_51.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_64.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_23.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_13.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_20.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_55.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_96.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_28.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_71.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_33.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_122.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videmmmmmmsss_102.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_65.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videmmmmmmsss_94.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videmmmmmmsss_86.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_33.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_3.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_13.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_1.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_48.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_4.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videmmmmmmsss_98.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_11.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_7.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_31.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_22.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_79.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_121.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_40.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_14.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_27.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_4.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_6.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_41.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_24.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_106.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_74.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_22.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_28.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_128.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videmmmmmmsss_90.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_2.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_0.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_82.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_118.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_52.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_2.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_73.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_15.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_44.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_63.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_56.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_91.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_32.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videppppsss_23.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/shop_lifter_65.mp4
# /kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet/shop lifters/videyyyyyyyyyss_11.mp4

# %% [markdown]
# # BLOCK 1: EDA

# %% [markdown]
# ## 1. Setup paths

# %%
import os
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = "/kaggle/input/datasets/mennathabett/shoplifting-dataset/Shop DataSet"

CLASS_DIRS = {
    "shop lifters": os.path.join(DATA_DIR, "shop lifters"),
    "non shop lifters": os.path.join(DATA_DIR, "non shop lifters"),
}

# %% [markdown]
# ## 2. Collect video file paths per class

# %%
video_records = []

for label, folder in CLASS_DIRS.items():
    if not os.path.isdir(folder):
        print(f"WARNING: folder not found -> {folder}")
        continue
    for fname in os.listdir(folder):
        if fname.lower().endswith((".mp4", ".avi", ".mov", ".mkv")):
            video_records.append({
                "filepath": os.path.join(folder, fname),
                "filename": fname,
                "label": label
            })

df = pd.DataFrame(video_records)
print(f"Total videos found: {len(df)}")
print(df["label"].value_counts())
# Out:
# Total videos found: 855
# label
# non shop lifters    531
# shop lifters        324
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Extract video metadata: frame count, fps, duration, resolution

# %%
def get_video_metadata(filepath):
    cap = cv2.VideoCapture(filepath)
    if not cap.isOpened():
        return None
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    duration = frame_count / fps if fps > 0 else 0
    cap.release()
    return {
        "frame_count": frame_count,
        "fps": fps,
        "width": width,
        "height": height,
        "duration_sec": duration
    }

metadata = []
for i, row in df.iterrows():
    meta = get_video_metadata(row["filepath"])
    if meta:
        meta.update({"filename": row["filename"], "label": row["label"]})
        metadata.append(meta)
    if i % 50 == 0:
        print(f"Processed {i}/{len(df)}")

meta_df = pd.DataFrame(metadata)
meta_df.to_csv("video_metadata.csv", index=False)
meta_df.head()
# Out:
# Processed 0/855
# Processed 50/855
# Processed 100/855
# Processed 150/855
# Processed 200/855
# Processed 250/855
# Processed 300/855
# Processed 350/855
# Processed 400/855
# Processed 450/855
# Processed 500/855
# Processed 550/855
# Processed 600/855
# Processed 650/855
# Processed 700/855
# Processed 750/855
# Processed 800/855
# Processed 850/855
#    frame_count    fps  width  height  duration_sec  \
# 0          248  24.75    704     576     10.020202
# 1          350  25.00    704     576     14.000000
# 2          273  24.75    704     576     11.030303
# 3          200  25.00    704     576      8.000000
# 4          325  25.00    704     576     13.000000
#
#                             filename         label
# 0                 shop_lifter_75.mp4  shop lifters
# 1         videyyyyyyzzzzzyyyss_0.mp4  shop lifters
# 2                 shop_lifter_83.mp4  shop lifters
# 3  videyyyyyynnnnnnzzzzzyyyss_23.mp4  shop lifters
# 4                 videppppsss_37.mp4  shop lifters

# %% [markdown]
# ## 4. Class distribution

# %%
plt.figure(figsize=(5,4))
meta_df["label"].value_counts().plot(kind="bar", color=["steelblue","salmon"])
plt.title("Number of Clips per Class")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

print(meta_df["label"].value_counts())
# Out:
# label
# non shop lifters    531
# shop lifters        324
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Remove Duplicate Clips (_1 suffix)

# %%
import re

def is_duplicate_suffix(filename):
    """
    Flags filenames ending in '_1' before the extension, e.g.
    shop_lifter_n_13_1.mp4 -> duplicate of shop_lifter_n_13.mp4
    """
    name_no_ext = os.path.splitext(filename)[0]
    return bool(re.search(r"_1$", name_no_ext))

# Identify duplicates
meta_df["is_duplicate"] = meta_df["filename"].apply(is_duplicate_suffix)

dup_counts = meta_df.groupby(["label", "is_duplicate"]).size()
print("Duplicate counts by label:")
print(dup_counts)

# Sanity check: confirm duplicates only exist in non shop lifters
dup_in_shoplifters = meta_df[(meta_df["label"] == "shop lifters") & (meta_df["is_duplicate"])]
print(f"\nDuplicates found in 'shop lifters' class: {len(dup_in_shoplifters)}")
# Out:
# Duplicate counts by label:
# label             is_duplicate
# non shop lifters  False           311
#                   True            220
# shop lifters      False           319
#                   True              5
# dtype: int64
#
# Duplicates found in 'shop lifters' class: 5

# %%
# Drop duplicates, keep only original clips
meta_df_clean = meta_df[~meta_df["is_duplicate"]].drop(columns=["is_duplicate"]).reset_index(drop=True)

print("Class distribution AFTER removing duplicates:")
print(meta_df_clean["label"].value_counts())

print(f"\nTotal videos before: {len(meta_df)}")
print(f"Total videos after:  {len(meta_df_clean)}")
# Out:
# Class distribution AFTER removing duplicates:
# label
# shop lifters        319
# non shop lifters    311
# Name: count, dtype: int64
#
# Total videos before: 855
# Total videos after:  630

# %%
# Overwrite meta_df with the cleaned version for all downstream blocks
meta_df = meta_df_clean.copy()
meta_df.to_csv("video_metadata_clean.csv", index=False)
plt.figure(figsize=(5,4))
meta_df["label"].value_counts().plot(kind="bar", color=["steelblue","salmon"])
plt.title("Number of Clips per Class")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

print(meta_df["label"].value_counts())
# Out:
# label
# shop lifters        319
# non shop lifters    311
# Name: count, dtype: int64

# %% [markdown]
# ## 6. Clip duration distribution

# %%
plt.figure(figsize=(7,4))
for label in meta_df["label"].unique():
    subset = meta_df[meta_df["label"] == label]
    plt.hist(subset["duration_sec"], bins=20, alpha=0.6, label=label)
plt.xlabel("Duration (seconds)")
plt.ylabel("Number of clips")
plt.title("Clip Duration Distribution by Class")
plt.legend()
plt.show()

print(meta_df.groupby("label")["duration_sec"].describe())
# Out:
#                   count       mean       std  min   25%   50%   75%        max
# label
# non shop lifters  311.0  13.809181  5.082835  3.0  11.0  14.0  16.0  74.000000
# shop lifters      319.0  12.214908  3.365842  4.0  10.0  12.0  15.0  23.030303

# %% [markdown]
# ## 7. Frame count distribution (important for sampling strategy later)

# %%
plt.figure(figsize=(7,4))
for label in meta_df["label"].unique():
    subset = meta_df[meta_df["label"] == label]
    plt.hist(subset["frame_count"], bins=20, alpha=0.6, label=label)
plt.xlabel("Total frame count")
plt.ylabel("Number of clips")
plt.title("Frame Count Distribution by Class")
plt.legend()
plt.show()

print(meta_df.groupby("label")["frame_count"].describe())
# Out:
#                   count        mean         std    min    25%    50%    75%  \
# label
# non shop lifters  311.0  344.610932  127.064727   75.0  275.0  348.0  400.0
# shop lifters      319.0  304.366771   83.735021  100.0  248.0  300.0  372.0
#
#                      max
# label
# non shop lifters  1850.0
# shop lifters       570.0

# %% [markdown]
# ## 8. Frame resolution check

# %%
print("Unique resolutions (width x height):")
print(meta_df.groupby(["width","height"]).size().sort_values(ascending=False))
# Out:
# Unique resolutions (width x height):
# width  height
# 704    576       630
# dtype: int64

# %% [markdown]
# ## 9. Sample a few frames visually from each class

# %%
def show_sample_frame(filepath, title=""):
    cap = cv2.VideoCapture(filepath)
    ret, frame = cap.read()
    cap.release()
    if ret:
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        plt.imshow(frame_rgb)
        plt.title(title)
        plt.axis("off")

plt.figure(figsize=(12,4))
for i, label in enumerate(meta_df["label"].unique()):
    sample_row = meta_df[meta_df["label"] == label].iloc[0]
    plt.subplot(1, 2, i+1)
    show_sample_frame(
        os.path.join(CLASS_DIRS[label], sample_row["filename"]),
        title=f"{label} (frames={sample_row['frame_count']}, dur={sample_row['duration_sec']:.1f}s)"
    )
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Outlier Inspection

# %%
# 1. Flag statistical outliers using IQR per class
def flag_outliers(df, col):
    outlier_rows = []
    for label in df["label"].unique():
        subset = df[df["label"] == label]
        Q1, Q3 = subset[col].quantile(0.25), subset[col].quantile(0.75)
        IQR = Q3 - Q1
        lower, upper = Q1 - 1.5*IQR, Q3 + 1.5*IQR
        out = subset[(subset[col] < lower) | (subset[col] > upper)]
        outlier_rows.append(out)
    return pd.concat(outlier_rows)

dur_outliers = flag_outliers(meta_df, "duration_sec")
frame_outliers = flag_outliers(meta_df, "frame_count")

print(f"Duration outliers: {len(dur_outliers)}")
print(dur_outliers[["filename","label","frame_count","fps","duration_sec"]].sort_values("duration_sec", ascending=False))

print(f"\nFrame count outliers: {len(frame_outliers)}")
print(frame_outliers[["filename","label","frame_count","fps","duration_sec"]].sort_values("frame_count", ascending=False))
# Out:
# Duration outliers: 7
#                   filename             label  frame_count    fps  duration_sec
# 368   shop_lifter_n_13.mp4  non shop lifters         1850  25.00     74.000000
# 332   shop_lifter_n_44.mp4  non shop lifters          900  25.00     36.000000
# 501  shop_lifter_n_206.mp4  non shop lifters          650  25.00     26.000000
# 419   shop_lifter_n_66.mp4  non shop lifters          625  25.00     25.000000
# 326     videppppsss_37.mp4  non shop lifters          596  24.83     24.003222
# 18      shop_lifter_39.mp4      shop lifters          570  24.75     23.030303
# 622  shop_lifter_n_215.mp4  non shop lifters           75  25.00      3.000000
#
# Frame count outliers: 7
#                   filename             label  frame_count    fps  duration_sec
# 368   shop_lifter_n_13.mp4  non shop lifters         1850  25.00     74.000000
# 332   shop_lifter_n_44.mp4  non shop lifters          900  25.00     36.000000
# 501  shop_lifter_n_206.mp4  non shop lifters          650  25.00     26.000000
# 419   shop_lifter_n_66.mp4  non shop lifters          625  25.00     25.000000
# 326     videppppsss_37.mp4  non shop lifters          596  24.83     24.003222
# 18      shop_lifter_39.mp4      shop lifters          570  24.75     23.030303
# 622  shop_lifter_n_215.mp4  non shop lifters           75  25.00      3.000000

# %%
# 2. Visually inspect the most extreme outlier(s)
def show_clip_frames(filepath, n=6, title=""):
    cap = cv2.VideoCapture(filepath)
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    idxs = np.linspace(0, total-1, n).astype(int)
    
    plt.figure(figsize=(15,3))
    for i, idx in enumerate(idxs):
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if ret:
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            plt.subplot(1, n, i+1)
            plt.imshow(frame_rgb)
            plt.title(f"f{idx}")
            plt.axis("off")
    cap.release()
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

# Inspect top 3 most extreme by frame_count
top_outliers = meta_df.sort_values("frame_count", ascending=False).head(3)
for _, row in top_outliers.iterrows():
    fp = os.path.join(CLASS_DIRS[row["label"]], row["filename"])
    show_clip_frames(fp, n=6, title=f"{row['filename']} | {row['label']} | {row['frame_count']} frames | {row['duration_sec']:.1f}s")

# %%
# 3. Check for near-duplicate / corrupted / zero-frame videos
zero_frame = meta_df[meta_df["frame_count"] <= 1]
print(f"Zero/near-zero frame videos: {len(zero_frame)}")
print(zero_frame)

low_fps = meta_df[meta_df["fps"] <= 1]
print(f"\nSuspiciously low fps videos: {len(low_fps)}")
print(low_fps)
# Out:
# Zero/near-zero frame videos: 0
# Empty DataFrame
# Columns: [frame_count, fps, width, height, duration_sec, filename, label]
# Index: []
#
# Suspiciously low fps videos: 0
# Empty DataFrame
# Columns: [frame_count, fps, width, height, duration_sec, filename, label]
# Index: []

# %% [markdown]
# # BLOCK 2: Frame Sampling Strategy

# %%
import cv2
import numpy as np

def compute_motion_scores(frames_gray):
    """
    Compute motion score for each frame index (except the first) as
    mean absolute pixel difference from the previous frame.
    Returns array of length len(frames_gray), first entry = 0.
    """
    scores = [0.0]
    for i in range(1, len(frames_gray)):
        diff = cv2.absdiff(frames_gray[i], frames_gray[i-1])
        scores.append(float(np.mean(diff)))
    return np.array(scores)


def sample_frame_indices(total_frames, T, motion_scores=None, uniform_ratio=0.5):
    """
    Hybrid frame sampling: part uniform coverage, part motion-biased.
    
    Args:
        total_frames: total number of frames in the video
        T: target number of frames to sample
        motion_scores: optional array (len=total_frames) of per-frame motion scores.
                        If None, falls back to pure uniform sampling.
        uniform_ratio: fraction of T reserved for uniform coverage (0-1)
    
    Returns:
        sorted list of T frame indices (chronological order)
    """
    if total_frames <= T:
        # short clip: just take every frame, pad by repeating last frame
        idxs = list(range(total_frames))
        while len(idxs) < T:
            idxs.append(total_frames - 1)
        return sorted(idxs)

    if motion_scores is None:
        # pure uniform fallback
        skip = total_frames // T
        idxs = [min(i * skip, total_frames - 1) for i in range(T)]
        return sorted(idxs)

    # --- Hybrid: uniform part + motion-biased part ---
    n_uniform = max(1, int(T * uniform_ratio))
    n_motion = T - n_uniform

    # 1. Uniform indices spanning full duration
    skip = total_frames // n_uniform
    uniform_idxs = [min(i * skip, total_frames - 1) for i in range(n_uniform)]

    # 2. Motion-biased indices: pick top motion-score frames,
    #    excluding ones already picked, with simple non-max suppression
    #    to avoid clustering all picks in one motion spike
    remaining_scores = motion_scores.copy()
    remaining_scores[uniform_idxs] = -1  # exclude already-selected

    motion_idxs = []
    min_gap = max(1, total_frames // (n_motion * 3))  # spacing to avoid clustering
    sorted_by_motion = np.argsort(remaining_scores)[::-1]

    for idx in sorted_by_motion:
        if remaining_scores[idx] < 0:
            continue
        if all(abs(idx - existing) >= min_gap for existing in motion_idxs):
            motion_idxs.append(int(idx))
        if len(motion_idxs) >= n_motion:
            break

    # fallback if not enough motion frames found (e.g. very short/static clip)
    while len(motion_idxs) < n_motion:
        candidate = np.random.randint(0, total_frames)
        if candidate not in motion_idxs and candidate not in uniform_idxs:
            motion_idxs.append(candidate)

    all_idxs = sorted(set(uniform_idxs + motion_idxs))
    
    # in rare case of overlap reducing count below T, top up uniformly
    while len(all_idxs) < T:
        candidate = np.random.randint(0, total_frames)
        if candidate not in all_idxs:
            all_idxs.append(candidate)
    all_idxs = sorted(all_idxs)[:T]

    return all_idxs

# %%
# Helper: read all frames (grayscale, downscaled) for motion scoring
def get_grayscale_frames(filepath, resize_to=(160, 120)):
    """
    Reads all frames from a video, converts to grayscale, resizes small
    for fast motion score computation.
    """
    cap = cv2.VideoCapture(filepath)
    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        gray = cv2.resize(gray, resize_to)
        frames.append(gray)
    cap.release()
    return frames

# %%
# Test the sampling strategy on a few clips
T = 16

test_row = meta_df.iloc[0]
fp = os.path.join(CLASS_DIRS[test_row["label"]], test_row["filename"])

gray_frames = get_grayscale_frames(fp)
motion_scores = compute_motion_scores(gray_frames)
selected_idxs = sample_frame_indices(len(gray_frames), T, motion_scores)

print(f"Video: {test_row['filename']} | total_frames={len(gray_frames)}")
print(f"Selected indices ({len(selected_idxs)}): {selected_idxs}")

# Visualize motion score curve with selected frames marked
plt.figure(figsize=(10,3))
plt.plot(motion_scores, label="motion score")
plt.scatter(selected_idxs, motion_scores[selected_idxs], color="red", zorder=5, label="sampled frames")
plt.xlabel("Frame index")
plt.ylabel("Motion score")
plt.title(f"Sampling: {test_row['filename']}")
plt.legend()
plt.show()
# Out:
# Video: shop_lifter_75.mp4 | total_frames=248
# Selected indices (16): [0, 1, 12, 31, 60, 62, 72, 93, 108, 120, 124, 155, 168, 186, 216, 217]

# %% [markdown]
# # BLOCK 3: PyTorch Dataset Class

# %%
import torch
from torch.utils.data import Dataset
import torchvision.transforms.functional as TF
import random
from PIL import Image

class ShopliftingDataset(Dataset):
    def __init__(self, df, class_dirs, T=16, frame_size=112, train=True):
        """
        df: metadata dataframe with 'filename' and 'label' columns
        class_dirs: dict mapping label -> folder path
        T: number of frames to sample per clip
        frame_size: output spatial size (square) after crop
        train: if True, apply random augmentation; if False, use center crop only
        """
        self.df = df.reset_index(drop=True)
        self.class_dirs = class_dirs
        self.T = T
        self.frame_size = frame_size
        self.train = train
        self.label_map = {"non shop lifters": 0, "shop lifters": 1}

    def __len__(self):
        return len(self.df)

    def _get_grayscale_frames(self, filepath, resize_to=(160, 120)):
        cap = cv2.VideoCapture(filepath)
        frames = []
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.resize(gray, resize_to)
            frames.append(gray)
        cap.release()
        return frames

    def _read_rgb_frame(self, cap, idx):
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if not ret:
            return None
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        return Image.fromarray(frame_rgb)

    def _sample_clip_augmentation_params(self, orig_size):
        """
        Sample ONE set of random augmentation params per clip,
        to be applied identically to every frame.
        """
        w, h = orig_size
        params = {}

        # random flip
        params["flip"] = random.random() < 0.5 if self.train else False

        # random crop box (or center crop for eval)
        crop_size = min(w, h)
        if self.train:
            max_x = w - crop_size
            max_y = h - crop_size
            params["crop_x"] = random.randint(0, max_x) if max_x > 0 else 0
            params["crop_y"] = random.randint(0, max_y) if max_y > 0 else 0
        else:
            params["crop_x"] = (w - crop_size) // 2
            params["crop_y"] = (h - crop_size) // 2
        params["crop_size"] = crop_size

        # color jitter factors (sampled once, applied to all frames)
        if self.train:
            params["brightness"] = random.uniform(0.8, 1.2)
            params["contrast"] = random.uniform(0.8, 1.2)
            params["saturation"] = random.uniform(0.8, 1.2)
        else:
            params["brightness"] = 1.0
            params["contrast"] = 1.0
            params["saturation"] = 1.0

        return params

    def _apply_clip_augmentation(self, img, params):
        # crop
        img = TF.crop(img, params["crop_y"], params["crop_x"],
                       params["crop_size"], params["crop_size"])
        # resize to target
        img = TF.resize(img, [self.frame_size, self.frame_size])
        # flip
        if params["flip"]:
            img = TF.hflip(img)
        # color jitter (same factors every frame)
        img = TF.adjust_brightness(img, params["brightness"])
        img = TF.adjust_contrast(img, params["contrast"])
        img = TF.adjust_saturation(img, params["saturation"])
        return img

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        label_str = row["label"]
        filepath = os.path.join(self.class_dirs[label_str], row["filename"])
        label = self.label_map[label_str]

        # 1. Motion-aware sampling (reuses functions from Block 2)
        gray_frames = self._get_grayscale_frames(filepath)
        total_frames = len(gray_frames)
        motion_scores = compute_motion_scores(gray_frames)
        selected_idxs = sample_frame_indices(total_frames, self.T, motion_scores)

        # 2. Open video once for RGB frame reads
        cap = cv2.VideoCapture(filepath)
        first_frame = self._read_rgb_frame(cap, selected_idxs[0])
        orig_size = first_frame.size  # (w, h)

        # 3. Sample ONE augmentation param set for the whole clip
        aug_params = self._sample_clip_augmentation_params(orig_size)

        # 4. Read + augment all T frames consistently
        frames_tensor = []
        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)  # reset just in case
        for f_idx in selected_idxs:
            img = self._read_rgb_frame(cap, f_idx)
            if img is None:
                img = frames_tensor[-1] if frames_tensor else Image.new("RGB", orig_size)
                img = TF.to_pil_image(img) if isinstance(img, torch.Tensor) else img
            img = self._apply_clip_augmentation(img, aug_params)
            img_tensor = TF.to_tensor(img)  # (C, H, W), values in [0,1]
            frames_tensor.append(img_tensor)
        cap.release()

        clip_tensor = torch.stack(frames_tensor, dim=0)  # (T, C, H, W)

        # 5. Normalize (ImageNet stats are fine as generic normalization even from-scratch)
        mean = torch.tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1)
        std = torch.tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1)
        clip_tensor = (clip_tensor - mean) / std

        return clip_tensor, label

# %%
# Sanity check the Dataset class 
from torch.utils.data import DataLoader

train_ds = ShopliftingDataset(meta_df, CLASS_DIRS, T=16, frame_size=112, train=True)
clip, label = train_ds[0]
print("Clip tensor shape:", clip.shape)   # (16, 3, 112, 112)
print("Label:", label)

# Check a batch via DataLoader
loader = DataLoader(train_ds, batch_size=4, shuffle=True, num_workers=2)
batch_clips, batch_labels = next(iter(loader))
print("Batch shape:", batch_clips.shape)  # (4, 16, 3, 112, 112)
print("Batch labels:", batch_labels)
# Out:
# Clip tensor shape: torch.Size([16, 3, 112, 112])
# Label: 1
# Batch shape: torch.Size([4, 16, 3, 112, 112])
# Batch labels: tensor([0, 1, 0, 0])

# %%
# Visual check: confirm augmentation is IDENTICAL across frames in a clip
def visualize_clip_tensor(clip_tensor, title=""):
    mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    plt.figure(figsize=(15, 3))
    for i in range(clip_tensor.shape[0]):
        img = clip_tensor[i] * std + mean
        img = img.permute(1, 2, 0).clamp(0, 1).numpy()
        plt.subplot(1, clip_tensor.shape[0], i + 1)
        plt.imshow(img)
        plt.axis("off")
    plt.suptitle(title)
    plt.tight_layout()
    plt.savefig("Sample_clip.png")
    plt.show()

visualize_clip_tensor(clip, title=f"Sample clip (label={label}) - check same crop/flip/color across all frames")

# %% [markdown]
# # BLOCK 4: From-Scratch 3D CNN Model

# %%
import torch
import torch.nn as nn

class Shoplifting3DCNN(nn.Module):
    def __init__(self, num_classes=2, dropout=0.5):
        super().__init__()

        # Input: (B, C, T, H, W) 
        # we'll permute from (B, T, C, H, W)
        self.features = nn.Sequential(
            # Block 1
            nn.Conv3d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm3d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2)),  # keep T, halve spatial

            # Block 2
            nn.Conv3d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2)),  # halve T and spatial

            # Block 3
            nn.Conv3d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2)),

            # Block 4
            nn.Conv3d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm3d(256),
            nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool3d((1, 1, 1)),  # global pool -> (B, 256, 1, 1, 1)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Dropout(dropout),
            nn.Linear(256, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            nn.Linear(128, num_classes),
        )

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv3d):
                nn.init.kaiming_normal_(m.weight, mode="fan_out", nonlinearity="relu")
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.BatchNorm3d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.zeros_(m.bias)

    def forward(self, x):
        # x comes in as (B, T, C, H, W) from the Dataset/DataLoader
        x = x.permute(0, 2, 1, 3, 4)  # -> (B, C, T, H, W) for Conv3d
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
# Sanity check: forward pass with a real batch 
model = Shoplifting3DCNN(num_classes=2)

# reuse batch_clips from Block 3's DataLoader check
out = model(batch_clips)
print("Output shape:", out.shape)  # (4, 2)
print("Output logits:\n", out)

# Param count
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\nTotal params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
# Out:
# Output shape: torch.Size([4, 2])
# Output logits:
#  tensor([[ 0.0060,  0.0033],
#         [-0.0004, -0.0018],
#         [ 0.0042, -0.0016],
#         [ 0.0088,  0.0043]], grad_fn=<AddmmBackward0>)
#
# Total params: 1,198,402
# Trainable params: 1,198,402

# %% [markdown]
# # BLOCK 5: Train/Val/Test Split

# %%
from sklearn.model_selection import train_test_split

# Stratified split to preserve class balance across sets
train_df, temp_df = train_test_split(
    meta_df, test_size=0.3, stratify=meta_df["label"], random_state=42
)
val_df, test_df = train_test_split(
    temp_df, test_size=0.5, stratify=temp_df["label"], random_state=42
)

print(f"Train: {len(train_df)} | Val: {len(val_df)} | Test: {len(test_df)}")
print("\nTrain distribution:\n", train_df["label"].value_counts())
print("\nVal distribution:\n", val_df["label"].value_counts())
print("\nTest distribution:\n", test_df["label"].value_counts())
# Out:
# Train: 441 | Val: 94 | Test: 95
#
# Train distribution:
#  label
# shop lifters        223
# non shop lifters    218
# Name: count, dtype: int64
#
# Val distribution:
#  label
# shop lifters        48
# non shop lifters    46
# Name: count, dtype: int64
#
# Test distribution:
#  label
# shop lifters        48
# non shop lifters    47
# Name: count, dtype: int64

# %% [markdown]
# # BLOCK 6: DataLoaders

# %%
train_ds = ShopliftingDataset(train_df, CLASS_DIRS, T=16, frame_size=112, train=True)
val_ds   = ShopliftingDataset(val_df,   CLASS_DIRS, T=16, frame_size=112, train=False)
test_ds  = ShopliftingDataset(test_df,  CLASS_DIRS, T=16, frame_size=112, train=False)

BATCH_SIZE = 8

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

print(f"Train batches: {len(train_loader)} | Val batches: {len(val_loader)} | Test batches: {len(test_loader)}")
# Out:
# Train batches: 56 | Val batches: 12 | Test batches: 12

# %% [markdown]
# # BLOCK 7: Training Setup

# %%
import torch.optim as optim
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = Shoplifting3DCNN(num_classes=2).to(device)

# class weights (in case balance isn't perfectly even)
class_counts = train_df["label"].value_counts()
weight_non = 1.0 / class_counts["non shop lifters"]
weight_shop = 1.0 / class_counts["shop lifters"]
class_weights = torch.tensor([weight_non, weight_shop], dtype=torch.float32).to(device)
class_weights = class_weights / class_weights.sum() * 2  # normalize

criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=3)
# Out:
# Using device: cuda

# %% [markdown]
# # BLOCK 8: Train / Eval Loop Functions

# %%
def run_epoch(model, loader, criterion, optimizer=None):
    is_train = optimizer is not None
    model.train() if is_train else model.eval()

    total_loss = 0.0
    all_preds, all_labels = [], []

    torch.set_grad_enabled(is_train)
    for clips, labels in loader:
        clips, labels = clips.to(device), labels.to(device)

        if is_train:
            optimizer.zero_grad()

        outputs = model(clips)
        loss = criterion(outputs, labels)

        if is_train:
            loss.backward()
            optimizer.step()

        total_loss += loss.item() * clips.size(0)
        preds = outputs.argmax(dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / len(loader.dataset)
    acc = accuracy_score(all_labels, all_preds)
    precision, recall, f1, _ = precision_recall_fscore_support(
        all_labels, all_preds, average="binary", zero_division=0
    )
    return avg_loss, acc, precision, recall, f1

# %% [markdown]
# # BLOCK 9: Training Loop

# %%
NUM_EPOCHS = 50
history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
best_val_f1 = 0.0
epochs_no_improve = 0
PATIENCE = 10  # stop if val F1 doesn't improve for this many epochs

for epoch in range(NUM_EPOCHS):
    train_loss, train_acc, train_prec, train_rec, train_f1 = run_epoch(model, train_loader, criterion, optimizer)
    val_loss, val_acc, val_prec, val_rec, val_f1 = run_epoch(model, val_loader, criterion, optimizer=None)

    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)

    print(f"Epoch {epoch+1}/{NUM_EPOCHS} | "
          f"Train Loss: {train_loss:.4f} Acc: {train_acc:.4f} F1: {train_f1:.4f} | "
          f"Val Loss: {val_loss:.4f} Acc: {val_acc:.4f} F1: {val_f1:.4f}")

    if val_f1 > best_val_f1:
        best_val_f1 = val_f1
        epochs_no_improve = 0
        torch.save(model.state_dict(), "best_model.pth")
        print(f"  -> New best model saved (Val F1: {val_f1:.4f})")
    else:
        epochs_no_improve += 1
        print(f"  -> No improvement for {epochs_no_improve}/{PATIENCE} epochs")

    if epochs_no_improve >= PATIENCE:
        print(f"\nEarly stopping triggered at epoch {epoch+1} (best Val F1: {best_val_f1:.4f})")
        break

print(f"\nTraining finished. Best Val F1: {best_val_f1:.4f}")
# Out:
# Epoch 1/50 | Train Loss: 0.6939 Acc: 0.4603 F1: 0.4080 | Val Loss: 0.6936 Acc: 0.5000 F1: 0.0408
#   -> New best model saved (Val F1: 0.0408)
# Epoch 2/50 | Train Loss: 0.6934 Acc: 0.4830 F1: 0.5529 | Val Loss: 0.6929 Acc: 0.5106 F1: 0.6761
#   -> New best model saved (Val F1: 0.6761)
# Epoch 3/50 | Train Loss: 0.6922 Acc: 0.5329 F1: 0.6023 | Val Loss: 0.6916 Acc: 0.5106 F1: 0.6761
#   -> No improvement for 1/10 epochs
# Epoch 5/50 | Train Loss: 0.6925 Acc: 0.5011 F1: 0.4634 | Val Loss: 0.6917 Acc: 0.4894 F1: 0.0000
#   -> No improvement for 3/10 epochs
# Epoch 6/50 | Train Loss: 0.6926 Acc: 0.5057 F1: 0.4467 | Val Loss: 0.6879 Acc: 0.5426 F1: 0.6906
#   -> New best model saved (Val F1: 0.6906)
# Epoch 7/50 | Train Loss: 0.6891 Acc: 0.5601 F1: 0.5975 | Val Loss: 0.6840 Acc: 0.5745 F1: 0.3103
#   -> No improvement for 1/10 epochs
# Epoch 8/50 | Train Loss: 0.6870 Acc: 0.5760 F1: 0.5760 | Val Loss: 0.6806 Acc: 0.5638 F1: 0.6822
#   -> No improvement for 2/10 epochs
# Epoch 9/50 | Train Loss: 0.6799 Acc: 0.5896 F1: 0.5486 | Val Loss: 0.6795 Acc: 0.5213 F1: 0.6809
#   -> No improvement for 3/10 epochs
# Epoch 10/50 | Train Loss: 0.6779 Acc: 0.6122 F1: 0.5778 | Val Loss: 0.6584 Acc: 0.5957 F1: 0.6607
#   -> No improvement for 4/10 epochs
# Epoch 11/50 | Train Loss: 0.6578 Acc: 0.6531 F1: 0.6400 | Val Loss: 0.6235 Acc: 0.6702 F1: 0.7048
#   -> New best model saved (Val F1: 0.7048)
# Epoch 12/50 | Train Loss: 0.6419 Acc: 0.6825 F1: 0.6759 | Val Loss: 0.5838 Acc: 0.7660 F1: 0.7660
#   -> New best model saved (Val F1: 0.7660)
# Epoch 13/50 | Train Loss: 0.5996 Acc: 0.7052 F1: 0.6875 | Val Loss: 0.8703 Acc: 0.5106 F1: 0.6761
#   -> No improvement for 1/10 epochs
# Epoch 14/50 | Train Loss: 0.5825 Acc: 0.7211 F1: 0.7248 | Val Loss: 0.5943 Acc: 0.7340 F1: 0.6575
#   -> No improvement for 2/10 epochs
# Epoch 15/50 | Train Loss: 0.5563 Acc: 0.7506 F1: 0.7511 | Val Loss: 0.7322 Acc: 0.5638 F1: 0.7007
#   -> No improvement for 3/10 epochs
# Epoch 16/50 | Train Loss: 0.5054 Acc: 0.7891 F1: 0.7862 | Val Loss: 0.7971 Acc: 0.5319 F1: 0.1538
#   -> No improvement for 4/10 epochs
# Epoch 17/50 | Train Loss: 0.4576 Acc: 0.8277 F1: 0.8296 | Val Loss: 1.3291 Acc: 0.5106 F1: 0.6761
#   -> No improvement for 5/10 epochs
# Epoch 18/50 | Train Loss: 0.4125 Acc: 0.8141 F1: 0.8178 | Val Loss: 0.3879 Acc: 0.8617 F1: 0.8471
#   -> New best model saved (Val F1: 0.8471)
# Epoch 19/50 | Train Loss: 0.3786 Acc: 0.8685 F1: 0.8705 | Val Loss: 0.3354 Acc: 0.8723 F1: 0.8723
#   -> New best model saved (Val F1: 0.8723)
# Epoch 20/50 | Train Loss: 0.3183 Acc: 0.8844 F1: 0.8874 | Val Loss: 1.5971 Acc: 0.5106 F1: 0.6761
#   -> No improvement for 1/10 epochs
# Epoch 21/50 | Train Loss: 0.3123 Acc: 0.8798 F1: 0.8830 | Val Loss: 0.4304 Acc: 0.7979 F1: 0.8348
#   -> No improvement for 2/10 epochs
# Epoch 22/50 | Train Loss: 0.3472 Acc: 0.8707 F1: 0.8719 | Val Loss: 0.2394 Acc: 0.9468 F1: 0.9505
#   -> New best model saved (Val F1: 0.9505)
# Epoch 23/50 | Train Loss: 0.2813 Acc: 0.8980 F1: 0.9007 | Val Loss: 0.1872 Acc: 0.9468 F1: 0.9505
#   -> No improvement for 1/10 epochs
# Epoch 24/50 | Train Loss: 0.3000 Acc: 0.8798 F1: 0.8809 | Val Loss: 0.3077 Acc: 0.8404 F1: 0.8148
#   -> No improvement for 2/10 epochs
# Epoch 25/50 | Train Loss: 0.2271 Acc: 0.9161 F1: 0.9169 | Val Loss: 0.3208 Acc: 0.8085 F1: 0.7692
#   -> No improvement for 3/10 epochs
# Epoch 26/50 | Train Loss: 0.2213 Acc: 0.9274 F1: 0.9289 | Val Loss: 0.0973 Acc: 0.9894 F1: 0.9897
#   -> New best model saved (Val F1: 0.9897)
# Epoch 27/50 | Train Loss: 0.2225 Acc: 0.9138 F1: 0.9156 | Val Loss: 0.7386 Acc: 0.5745 F1: 0.2857
#   -> No improvement for 1/10 epochs
# Epoch 28/50 | Train Loss: 0.2417 Acc: 0.9138 F1: 0.9167 | Val Loss: 0.4689 Acc: 0.6809 F1: 0.5455
#   -> No improvement for 2/10 epochs
# Epoch 29/50 | Train Loss: 0.2347 Acc: 0.9161 F1: 0.9172 | Val Loss: 0.1288 Acc: 0.9787 F1: 0.9796
#   -> No improvement for 3/10 epochs
# Epoch 30/50 | Train Loss: 0.1550 Acc: 0.9569 F1: 0.9577 | Val Loss: 0.0738 Acc: 0.9894 F1: 0.9895
#   -> No improvement for 4/10 epochs
# Epoch 31/50 | Train Loss: 0.1501 Acc: 0.9524 F1: 0.9526 | Val Loss: 0.5422 Acc: 0.7553 F1: 0.8067
#   -> No improvement for 5/10 epochs
# Epoch 32/50 | Train Loss: 0.1640 Acc: 0.9478 F1: 0.9490 | Val Loss: 0.0844 Acc: 0.9894 F1: 0.9895
#   -> No improvement for 6/10 epochs
# Epoch 33/50 | Train Loss: 0.2458 Acc: 0.9093 F1: 0.9091 | Val Loss: 0.7835 Acc: 0.6170 F1: 0.7273
#   -> No improvement for 7/10 epochs
# Epoch 34/50 | Train Loss: 0.1252 Acc: 0.9683 F1: 0.9689 | Val Loss: 0.1484 Acc: 0.9255 F1: 0.9320
#   -> No improvement for 8/10 epochs
# Epoch 35/50 | Train Loss: 0.1066 Acc: 0.9660 F1: 0.9664 | Val Loss: 0.1074 Acc: 0.9468 F1: 0.9505
#   -> No improvement for 9/10 epochs
# Epoch 36/50 | Train Loss: 0.1194 Acc: 0.9637 F1: 0.9643 | Val Loss: 0.1188 Acc: 0.9574 F1: 0.9565
#   -> No improvement for 10/10 epochs
#
# Early stopping triggered at epoch 36 (best Val F1: 0.9897)
#
# Training finished. Best Val F1: 0.9897

# %% [markdown]
# # BLOCK 10: Test Set Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Load best checkpoint (based on val F1)
model.load_state_dict(torch.load("best_model.pth"))
model.eval()

test_loss, test_acc, test_prec, test_rec, test_f1 = run_epoch(model, test_loader, criterion, optimizer=None)

print("=" * 50)
print("FINAL TEST SET RESULTS")
print("=" * 50)
print(f"Loss:      {test_loss:.4f}")
print(f"Accuracy:  {test_acc:.4f}")
print(f"Precision: {test_prec:.4f}")
print(f"Recall:    {test_rec:.4f}")
print(f"F1-score:  {test_f1:.4f}")
# Out:
# ==================================================
# FINAL TEST SET RESULTS
# ==================================================
# Loss:      0.1065
# Accuracy:  0.9684
# Precision: 0.9592
# Recall:    0.9792
# F1-score:  0.9691

# %%
# Detailed predictions for confusion matrix + full classification report
model.eval()
all_preds, all_labels = [], []

with torch.no_grad():
    for clips, labels in test_loader:
        clips = clips.to(device)
        outputs = model(clips)
        preds = outputs.argmax(dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(labels.numpy())

# Confusion matrix
cm = confusion_matrix(all_labels, all_preds)
label_names = ["non shop lifters", "shop lifters"]

plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_names, yticklabels=label_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Test Set")
plt.tight_layout()
plt.show()

print("\nFull Classification Report:")
print(classification_report(all_labels, all_preds, target_names=label_names, digits=4))
# Out:
# Full Classification Report:
#                   precision    recall  f1-score   support
#
# non shop lifters     0.9783    0.9574    0.9677        47
#     shop lifters     0.9592    0.9792    0.9691        48
#
#         accuracy                         0.9684        95
#        macro avg     0.9687    0.9683    0.9684        95
#     weighted avg     0.9686    0.9684    0.9684        95

# %%
# Training Curves
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history["train_loss"], label="Train Loss")
axes[0].plot(history["val_loss"], label="Val Loss")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].set_title("Loss Curve")
axes[0].legend()

axes[1].plot(history["train_acc"], label="Train Acc")
axes[1].plot(history["val_acc"], label="Val Acc")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")
axes[1].set_title("Accuracy Curve")
axes[1].legend()

plt.tight_layout()
plt.savefig("training_curves.png", dpi=150)
plt.show()
